# %%
import network
import pandas as pd
import utils

# %% [markdown]
# #### One hour simulation

# %%
net = network.WaterDistributionNetwork("anytown.inp")

# %%
utils.time_parameters_summary(net)
# Out:
# ('EN_DURATION', 0)
# ('EN_HYDSTEP', 60)
# ('EN_QUALSTEP', 60)
# ('EN_PATTERNSTEP', 3600)
# ('EN_PATTERNSTART', 0)
# ('EN_REPORTSTEP', 3600)
# ('EN_REPORTSTART', 0)
# ('EN_RULESTEP', 6)
# ('EN_STATISTIC', 0)
# ('EN_PERIODS', 0)
# ('EN_STARTTIME', 64800)

# %%
net.set_time_params(duration=3600)
net.run()

# %%
net.df_junctions_report
# Out:
# id                  1                                 2                        \
# properties       head   pressure      demand       head   pressure     demand
# 00:00:00    90.964317  84.868317  113.565002  69.215228  53.975228  45.425999
# 00:00:01    90.964080  84.868080  113.565002  69.213835  53.973835  45.425999
# 00:00:02    79.796610  73.700610  113.565002 -13.991734 -29.231734  45.425999
# 00:01:02    79.796610  73.700610  113.565002 -13.991731 -29.231731  45.425999
# 00:02:02    79.796610  73.700610  113.565002 -13.991731 -29.231731  45.425999
# ...               ...        ...         ...        ...        ...        ...
# 00:56:02    79.796610  73.700610  113.565002 -13.991731 -29.231731  45.425999
# 00:57:02    79.796610  73.700610  113.565002 -13.991731 -29.231731  45.425999
# 00:58:02    79.796610  73.700610  113.565002 -13.991731 -29.231731  45.425999
# 00:59:02    79.796610  73.700610  113.565002 -13.991731 -29.231731  45.425999
# 01:00:00    79.796610  73.700610  113.565002 -13.991731 -29.231731  45.425999
#
# id                  3                                4  ...          19  \
# properties       head   pressure     demand       head  ...      demand
# 00:00:00    62.247897  47.007897  45.425999  58.464487  ...  227.130005
# 00:00:01    62.246316  47.006316  45.425999  58.462764  ...  227.130005
# 00:00:02   -28.998391 -44.238391  45.425999 -39.258673  ...  227.130005
# 00:01:02   -28.998387 -44.238387  45.425999 -39.258667  ...  227.130005
# 00:02:02   -28.998386 -44.238386  45.425999 -39.258667  ...  227.130005
# ...               ...        ...        ...        ...  ...         ...
# 00:56:02   -28.998386 -44.238386  45.425999 -39.258667  ...  227.130005
# 00:57:02   -28.998387 -44.238387  45.425999 -39.258667  ...  227.130005
# 00:58:02   -28.998386 -44.238386  45.425999 -39.258667  ...  227.130005
# 00:59:02   -28.998386 -44.238386  45.425999 -39.258667  ...  227.130005
# 01:00:00   -28.998386 -44.238386  45.425999 -39.258667  ...  227.130005
#
# id                 20                           21                    \
# properties       head   pressure demand       head   pressure demand
# 00:00:00    90.979576  84.883576    0.0  69.583387  54.343387    0.0
# 00:00:01    90.979340  84.883340    0.0  69.581942  54.341942    0.0
# 00:00:02    79.857610  73.761610    0.0 -27.463717 -42.703717    0.0
# 00:01:02    79.857610  73.761610    0.0 -27.463714 -42.703714    0.0
# 00:02:02    79.857610  73.761610    0.0 -27.463714 -42.703714    0.0
# ...               ...        ...    ...        ...        ...    ...
# 00:56:02    79.857610  73.761610    0.0 -27.463714 -42.703714    0.0
# 00:57:02    79.857610  73.761610    0.0 -27.463714 -42.703714    0.0
# 00:58:02    79.857610  73.761610    0.0 -27.463714 -42.703714    0.0
# 00:59:02    79.857610  73.761610    0.0 -27.463714 -42.703714    0.0
# 01:00:00    79.857610  73.761610    0.0 -27.463714 -42.703714    0.0
#
# id                 22
# properties       head   pressure demand
# 00:00:00    69.577451  33.001451    0.0
# 00:00:01    69.574711  32.998711    0.0
# 00:00:02   -47.659855 -84.235855    0.0
# 00:01:02   -47.659880 -84.235880    0.0
# 00:02:02   -47.659879 -84.235879    0.0
# ...               ...        ...    ...
# 00:56:02   -47.659879 -84.235879    0.0
# 00:57:02   -47.659880 -84.235880    0.0
# 00:58:02   -47.659879 -84.235879    0.0
# 00:59:02   -47.659879 -84.235879    0.0
# 01:00:00   -47.659879 -84.235879    0.0
#
# [63 rows x 66 columns]

# %% [markdown]
# #### With random demand pattern (24h)

# %%
import random

new_pattern = []
for i in range(0, 24):
    new_pattern.append(round(random.uniform(0.5,1.5), 2))

new_pattern = pd.Series(new_pattern)
new_pattern
# Out:
# 0     0.92
# 1     0.60
# 2     1.04
# 3     1.06
# 4     0.82
# 5     0.58
# 6     0.84
# 7     0.67
# 8     0.84
# 9     0.53
# 10    0.57
# 11    0.56
# 12    1.06
# 13    0.65
# 14    1.22
# 15    0.60
# 16    0.85
# 17    0.91
# 18    1.40
# 19    1.15
# 20    0.74
# 21    0.90
# 22    1.44
# 23    0.68
# dtype: float64

# %%
net2 = network.WaterDistributionNetwork("anytown.inp")
net2.set_time_params(duration=86400, hydraulic_step=600) # duration=24h, hydstep=10min
net2.set_basedemand_pattern('2', new_pattern)

# %%
net2.run()
# Out:
# c:\users\david\appdata\local\programs\python\python36\lib\site-packages\epynet\epanet2.py:677: UserWarning: WARNING: System has negative pressures.
#   warnings.warn(self.ENgeterror(ierr))

# %%
net2.df_junctions_report.sample(10)
# Out:
# id                  1                                 2                        \
# properties       head   pressure      demand       head   pressure     demand
# 10:00:00    89.368327  83.272327   64.732051  56.252983  41.012983  25.892819
# 10:20:00    89.368327  83.272327   64.732051  56.252983  41.012983  25.892819
# 03:10:00    77.997436  71.901436  120.378902 -26.478265 -41.718265  48.151559
# 14:40:00    73.197968  67.101968  138.549302 -62.348182 -77.588182  55.419719
# 19:30:00    75.298032  69.202032  130.599752 -46.197751 -61.437751  52.239899
# 12:20:00    77.997436  71.901436  120.378902 -26.478265 -41.718265  48.151559
# 17:10:00    82.494720  76.398720  103.344152   3.736925 -11.503075  41.337659
# 20:00:00    86.562725  80.466725   84.038101  32.863737  17.623737  33.615239
# 05:00:00    89.203374  83.107374   65.867701  55.004038  39.764038  26.347079
# 10:50:00    89.368327  83.272327   64.732051  56.252983  41.012983  25.892819
#
# id                  3                                4  ...          19  \
# properties       head   pressure     demand       head  ...      demand
# 10:00:00    50.954345  35.714345  25.892819  47.331585  ...  129.464103
# 10:20:00    50.954345  35.714345  25.892819  47.331585  ...  129.464103
# 03:10:00   -43.194958 -58.434958  48.151559 -54.624417  ...  240.757805
# 14:40:00   -84.036320 -99.276320  55.419719 -98.864832  ...  277.098606
# 19:30:00   -65.637751 -80.877751  52.239899 -78.929178  ...  261.199506
# 12:20:00   -43.194958 -58.434958  48.151559 -54.624417  ...  240.757805
# 17:10:00    -8.864759 -24.104759  41.337659 -17.480724  ...  206.688305
# 20:00:00    24.271602   9.031602  33.615239  18.397026  ...  168.076204
# 05:00:00    49.531956  34.291956  26.347079  45.790608  ...  131.735403
# 10:50:00    50.954345  35.714345  25.892819  47.331585  ...  129.464103
#
# id                 20                           21                    \
# properties       head   pressure demand       head   pressure demand
# 10:00:00    89.389865  83.293865    0.0  51.496214  36.256214    0.0
# 10:20:00    89.389865  83.293865    0.0  51.496214  36.256214    0.0
# 03:10:00    78.065387  71.969387    0.0 -41.485406 -56.725406    0.0
# 14:40:00    73.286127  67.190127    0.0 -81.818354 -97.058354    0.0
# 19:30:00    75.377053  69.281053    0.0 -63.649695 -78.889695    0.0
# 12:20:00    78.065387  71.969387    0.0 -41.485406 -56.725406    0.0
# 17:10:00    82.545944  76.449944    0.0  -7.576035 -22.816035    0.0
# 20:00:00    86.597650  80.501650    0.0  25.150283   9.910283    0.0
# 05:00:00    89.225617  83.129617    0.0  50.091562  34.851562    0.0
# 10:50:00    89.389865  83.293865    0.0  51.496213  36.256213    0.0
#
# id                  22
# properties        head    pressure demand
# 10:00:00     44.365233    7.789233    0.0
# 10:20:00     44.365233    7.789233    0.0
# 03:10:00    -63.982963 -100.558963    0.0
# 14:40:00   -111.006552 -147.582552    0.0
# 19:30:00    -89.812319 -126.388319    0.0
# 12:20:00    -63.982963 -100.558963    0.0
# 17:10:00    -24.535556  -61.111556    0.0
# 20:00:00     13.586868  -22.989132    0.0
# 05:00:00     42.727157    6.151157    0.0
# 10:50:00     44.365233    7.789233    0.0
#
# [10 rows x 66 columns]
