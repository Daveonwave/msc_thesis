# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
train = 1
seed = 0
csv_file = 'saved_variables/train_' + str(train) + '/scada_values_' + str(seed) + '.csv'

df = pd.read_csv(csv_file)
df
# Out:
#       iteration                   timestamp  P78  P79       T41        J20  \
# 0             1  2021-10-20 14:44:42.311456  0.0  0.0  0.000000   0.000000
# 1             2  2021-10-20 14:44:47.113812  1.0  0.0  3.479931  85.984833
# 2             3  2021-10-20 14:44:52.402091  1.0  0.0  3.479931  85.984833
# 3             4  2021-10-20 14:44:57.774349  1.0  0.0  3.833111  85.996536
# 4             5  2021-10-20 14:45:04.142237  0.0  0.0  4.205117  81.089073
# ...         ...                         ...  ...  ...       ...        ...
# 1004       1005  2021-10-20 16:07:20.850211  0.0  1.0  3.048000  76.507133
# 1005       1006  2021-10-20 16:07:26.206088  0.0  1.0  3.048000  76.507133
# 1006       1007  2021-10-20 16:07:30.762099  0.0  1.0  3.048000  76.507133
# 1007       1008  2021-10-20 16:07:34.790102  0.0  1.0  3.048000  76.507133
# 1008       1008  2021-10-20 16:07:36.390037  0.0  1.0  3.048000  76.507133
#
# ...

# %%
df.columns.values
# Out:
# array(['iteration', 'timestamp', 'P78', 'P79', 'T41', 'J20', 'J20D',
#        'J20B', 'J21', 'J21D', 'J21B', 'J14', 'J14D', 'J14B', 'J2', 'J2D',
#        'J2B', 'J13', 'J13D', 'J13B', 'J1', 'J1D', 'J1B', 'J3', 'J3D',
#        'J3B', 'J6', 'J6D', 'J6B', 'J15', 'J15D', 'J15B', 'J5', 'J5D',
#        'J5B', 'J19', 'J19D', 'J19B', 'T42', 'J4', 'J4D', 'J4B', 'J18',
#        'J18D', 'J18B', 'J12', 'J12D', 'J12B', 'J7', 'J7D', 'J7B', 'J8',
#        'J8D', 'J8B', 'J16', 'J16D', 'J16B', 'J17', 'J17D', 'J17B', 'J11',
#        'J11D', 'J11B', 'J10', 'J10D', 'J10B', 'J9', 'J9D', 'J9B', 'J22',
#        'J22D', 'J22B'], dtype=object)

# %%
demand_patterns = pd.read_csv('demand_patterns_test.csv')

# %%
fig, axs = plt.subplots(3, 2, figsize=(20,20))

axs[0][0].plot(demand_patterns['2'])
axs[0][0].set_title('demand_pattern')

axs[0][1].plot(df['iteration'] / 6, df['T41'])
axs[0][1].set_title('T41_level')

axs[1][0].plot(df['iteration'] / 6, df['T42'])
axs[1][0].set_title('T42_level')

axs[1][1].plot(df['iteration'] / 6, df['J20'])
axs[1][1].set_title('J20_level')

axs[2][0].plot(df['P78'])
axs[2][0].set_title('P78_status')

axs[2][1].plot(df['iteration'] / 6, df['J4D'])
axs[2][1].set_title('J4_supply')
# Out:
# Text(0.5, 1.0, 'J4_supply')

# %%
train = 1
seed = 5
csv_scada = 'saved_variables/train_' + str(train) + '/scada_values_' + str(seed) + '.csv'
csv_ground = 'saved_variables/train_' + str(train) + '/ground_truth_' + str(seed) + '.csv'

df_scada = pd.read_csv(csv_scada)
df_ground = pd.read_csv(csv_ground)

# %%
f, ax = plt.subplots(figsize=(20,7))

ax.plot(df_scada['P78'], label='SCADA')
ax.plot(df_ground['P78_STATUS'], label='GROUND', alpha=0.5)
